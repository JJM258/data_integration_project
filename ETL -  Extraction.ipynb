# %% [markdown]
# # Data Extraction

# %%
df_2018 = spark.read.csv("/Volumes/etl_project/etl_schema/etl_data/condicionamentos/condicionamentostransito2018.csv", header = True, inferSchema= True)
df_2019 = spark.read.csv("/Volumes/etl_project/etl_schema/etl_data/condicionamentos/condicionamentostransito2019.csv", header = True, inferSchema= True)
df_2020 = spark.read.csv("/Volumes/etl_project/etl_schema/etl_data/condicionamentos/condicionamentostransito2020.csv", header = True, inferSchema= True)
df_2021 = spark.read.csv("/Volumes/etl_project/etl_schema/etl_data/condicionamentos/condicionamentostransito2021.csv", header = True, inferSchema= True)

# %%
print(f"Loaded Dataset: {df_2018.count()} rows, {len(df_2018.columns)} columns")
print(f"Loaded Dataset: {df_2019.count()} rows, {len(df_2019.columns)} columns")
print(f"Loaded Dataset: {df_2020.count()} rows, {len(df_2020.columns)} columns")
print(f"Loaded Dataset: {df_2021.count()} rows, {len(df_2021.columns)} columns")

# %%
df_2018.printSchema()
df_2018.show(5)

# %%
df_2018.write.saveAsTable("etl_project.etl_schema.df_raw_2018")
df_2019.write.saveAsTable("etl_project.etl_schema.df_raw_2019")
df_2020.write.saveAsTable("etl_project.etl_schema.df_raw_2020")
df_2021.write.saveAsTable("etl_project.etl_schema.df_raw_2021")
